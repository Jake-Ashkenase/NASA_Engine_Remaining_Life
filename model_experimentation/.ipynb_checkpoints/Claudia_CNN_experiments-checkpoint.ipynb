# %% [markdown]
# # Setup
# We need datasets, dataloaders, and code to train and evaluate models

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import os
import sys
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)
from models import *
from data_structures import *
from helpers import load_from_hdf5

# %%
X, y = load_from_hdf5("../../sample_windows.h5")
class_count = 10
int_y = (y // class_count)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

# %% [markdown]
# # 1d CNN
# First, let's try a one dimensional CNN to capture temporal relationships within each feature.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, int_y, max_samples_per_class=20000)

# %%
num_feats = 44
model = CNNRULClassifier(num_features=num_feats, num_classes=class_count).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20 

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 1.9025, Test Loss: 1.3157
# Epoch 2/20, Train Loss: 1.0361, Test Loss: 0.8363
# Epoch 3/20, Train Loss: 0.7475, Test Loss: 0.6797
# Epoch 4/20, Train Loss: 0.6402, Test Loss: 0.6077
# Epoch 5/20, Train Loss: 0.5823, Test Loss: 0.5616
# Epoch 6/20, Train Loss: 0.5422, Test Loss: 0.5264
# Epoch 7/20, Train Loss: 0.5094, Test Loss: 0.5024
# Epoch 8/20, Train Loss: 0.4802, Test Loss: 0.4692
# Epoch 9/20, Train Loss: 0.4535, Test Loss: 0.4444
# Epoch 10/20, Train Loss: 0.4290, Test Loss: 0.4243
# Epoch 11/20, Train Loss: 0.4067, Test Loss: 0.3973
# Epoch 12/20, Train Loss: 0.3860, Test Loss: 0.3776
# Epoch 13/20, Train Loss: 0.3659, Test Loss: 0.3594
# Epoch 14/20, Train Loss: 0.3460, Test Loss: 0.3438
# Epoch 15/20, Train Loss: 0.3280, Test Loss: 0.3218
# Epoch 16/20, Train Loss: 0.3119, Test Loss: 0.3068
# Epoch 17/20, Train Loss: 0.2967, Test Loss: 0.2965
# Epoch 18/20, Train Loss: 0.2832, Test Loss: 0.2781
# Epoch 19/20, Train Loss: 0.2712, Test Loss: 0.2685
# Epoch 20/20, Train Loss: 0.2599, Test Loss: 0.2656

# %%
plot_loss(history)

# %%
pred_rul, actual_rul = model.get_predict_and_true(test_loader, device)
acc = calculate_accuracy(pred_rul, actual_rul) * 100
print(f"Model Accuracy: {acc:.2f}%")
# Out:
# Model Accuracy: 88.22%

# %%
plot_confusion_matrix(actual_rul, pred_rul)

# %% [markdown]
# # 2d CNN
# Now, let's try out a two dimensional CNN to capture interactions among features.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, int_y, max_samples_per_class=20000, dim="2d")

# %%
num_feats = 44
model = CNNRUL2DClassifier(num_features=num_feats, num_classes=class_count).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20 

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 1.9931, Test Loss: 1.6312
# Epoch 2/20, Train Loss: 1.3377, Test Loss: 1.0098
# Epoch 3/20, Train Loss: 0.8028, Test Loss: 0.6447
# Epoch 4/20, Train Loss: 0.5577, Test Loss: 0.4940
# Epoch 5/20, Train Loss: 0.4585, Test Loss: 0.4283
# Epoch 6/20, Train Loss: 0.4067, Test Loss: 0.3906
# Epoch 7/20, Train Loss: 0.3708, Test Loss: 0.3587
# Epoch 8/20, Train Loss: 0.3419, Test Loss: 0.3311
# Epoch 9/20, Train Loss: 0.3172, Test Loss: 0.3094
# Epoch 10/20, Train Loss: 0.2946, Test Loss: 0.2859
# Epoch 11/20, Train Loss: 0.2737, Test Loss: 0.2684
# Epoch 12/20, Train Loss: 0.2526, Test Loss: 0.2447
# Epoch 13/20, Train Loss: 0.2313, Test Loss: 0.2243
# Epoch 14/20, Train Loss: 0.2103, Test Loss: 0.2038
# Epoch 15/20, Train Loss: 0.1890, Test Loss: 0.1828
# Epoch 16/20, Train Loss: 0.1690, Test Loss: 0.1678
# Epoch 17/20, Train Loss: 0.1492, Test Loss: 0.1442
# Epoch 18/20, Train Loss: 0.1315, Test Loss: 0.1278
# Epoch 19/20, Train Loss: 0.1159, Test Loss: 0.1132
# Epoch 20/20, Train Loss: 0.1017, Test Loss: 0.1053

# %%
plot_loss(history)

# %%
pred_rul, actual_rul = model.get_predict_and_true(test_loader, device)
acc = calculate_accuracy(pred_rul, actual_rul) * 100
print(f"Model Accuracy: {acc:.2f}%")
# Out:
# Model Accuracy: 96.18%

# %%
plot_confusion_matrix(actual_rul, pred_rul)

# %% [markdown]
# # Hybrid CNN
# Now, let's try a hybrid CNN that uses both 1d and 2d convolutions.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, int_y, max_samples_per_class=20000)

# %%
num_feats = 44
model = HybridCNNClassifier(num_features=num_feats,seq_length=50, num_classes=class_count).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20 

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 1.2876, Test Loss: 0.8242
# Epoch 2/20, Train Loss: 0.6749, Test Loss: 0.5731
# Epoch 3/20, Train Loss: 0.5072, Test Loss: 0.4572
# Epoch 4/20, Train Loss: 0.4119, Test Loss: 0.3775
# Epoch 5/20, Train Loss: 0.3452, Test Loss: 0.3197
# Epoch 6/20, Train Loss: 0.2946, Test Loss: 0.2739
# Epoch 7/20, Train Loss: 0.2547, Test Loss: 0.2382
# Epoch 8/20, Train Loss: 0.2222, Test Loss: 0.2094
# Epoch 9/20, Train Loss: 0.1952, Test Loss: 0.1846
# Epoch 10/20, Train Loss: 0.1734, Test Loss: 0.1648
# Epoch 11/20, Train Loss: 0.1541, Test Loss: 0.1466
# Epoch 12/20, Train Loss: 0.1383, Test Loss: 0.1327
# Epoch 13/20, Train Loss: 0.1248, Test Loss: 0.1210
# Epoch 14/20, Train Loss: 0.1133, Test Loss: 0.1094
# Epoch 15/20, Train Loss: 0.1032, Test Loss: 0.1007
# Epoch 16/20, Train Loss: 0.0947, Test Loss: 0.0920
# Epoch 17/20, Train Loss: 0.0870, Test Loss: 0.0865
# Epoch 18/20, Train Loss: 0.0804, Test Loss: 0.0789
# Epoch 19/20, Train Loss: 0.0742, Test Loss: 0.0745
# Epoch 20/20, Train Loss: 0.0694, Test Loss: 0.0722

# %%
plot_loss(history)

# %%
pred_rul, actual_rul = model.get_predict_and_true(test_loader, device)
acc = calculate_accuracy(pred_rul, actual_rul) * 100
print(f"Model Accuracy: {acc:.2f}%")
# Out:
# Model Accuracy: 98.38%

# %%
plot_confusion_matrix(actual_rul, pred_rul)
