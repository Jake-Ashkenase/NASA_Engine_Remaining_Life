# %% [markdown]
# # Setup
# We need datasets, dataloaders, and code to train and evaluate models

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import os
import sys
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)
from models import *
from data_structures import *
from helpers import load_from_hdf5

# %%
X, y = load_from_hdf5(filename="../../sample_windows.h5")

# %% [markdown]
# # 1d CNN
# First, let's try a one dimensional CNN to capture temporal relationships within each feature.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

# %%
num_feats = 44
model = CNNRULRegression(num_features=num_feats).to(device)
criterion = nn.MSELoss() 
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 15 

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/15, Train Loss: 445.8118, Test Loss: 149.8599
# Epoch 2/15, Train Loss: 113.7237, Test Loss: 88.1503
# Epoch 3/15, Train Loss: 72.8151, Test Loss: 57.6539
# Epoch 4/15, Train Loss: 44.7822, Test Loss: 35.0460
# Epoch 5/15, Train Loss: 29.8801, Test Loss: 25.5696
# Epoch 6/15, Train Loss: 23.1890, Test Loss: 20.8088
# Epoch 7/15, Train Loss: 18.4620, Test Loss: 15.9021
# Epoch 8/15, Train Loss: 14.0849, Test Loss: 11.9494
# Epoch 9/15, Train Loss: 10.3741, Test Loss: 8.5868
# Epoch 10/15, Train Loss: 7.3707, Test Loss: 5.9629
# Epoch 11/15, Train Loss: 5.0829, Test Loss: 4.1325
# Epoch 12/15, Train Loss: 3.8047, Test Loss: 4.2424
# Epoch 13/15, Train Loss: 3.0546, Test Loss: 2.8853
# Epoch 14/15, Train Loss: 2.5852, Test Loss: 2.4819
# Epoch 15/15, Train Loss: 2.2567, Test Loss: 2.0905

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # 2d CNN
# Now, let's try out a two dimensional CNN to capture interactions among features.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y, dim="2d")

# %%
num_feats = 44
model = CNNRUL2DRegression(num_features=num_feats).to(device)
criterion = nn.MSELoss() 
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 15 

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/15, Train Loss: 419.0082, Test Loss: 136.8853
# Epoch 2/15, Train Loss: 70.9157, Test Loss: 45.0460
# Epoch 3/15, Train Loss: 31.4532, Test Loss: 20.4034
# Epoch 4/15, Train Loss: 14.9023, Test Loss: 10.7415
# Epoch 5/15, Train Loss: 8.6184, Test Loss: 6.6688
# Epoch 6/15, Train Loss: 5.5249, Test Loss: 4.4289
# Epoch 7/15, Train Loss: 3.7313, Test Loss: 2.9937
# Epoch 8/15, Train Loss: 2.5978, Test Loss: 2.1394
# Epoch 9/15, Train Loss: 1.8871, Test Loss: 1.5975
# Epoch 10/15, Train Loss: 1.4212, Test Loss: 1.2664
# Epoch 11/15, Train Loss: 1.0782, Test Loss: 1.0027
# Epoch 12/15, Train Loss: 0.8657, Test Loss: 0.7647
# Epoch 13/15, Train Loss: 0.7266, Test Loss: 0.6671
# Epoch 14/15, Train Loss: 0.6167, Test Loss: 0.6101
# Epoch 15/15, Train Loss: 0.5310, Test Loss: 0.5032

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # Hybrid CNN
# Now, let's try a hybrid CNN that uses both 1d and 2d convolutions.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y)

# %%
num_feats = 44
seq_length = 50  
model = HybridCNNRegression(num_features=num_feats, seq_length=seq_length).to(device)
criterion = nn.MSELoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 15

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/15, Train Loss: 290.6986, Test Loss: 99.0802
# Epoch 2/15, Train Loss: 74.1606, Test Loss: 53.4389
# Epoch 3/15, Train Loss: 40.1405, Test Loss: 29.8132
# Epoch 4/15, Train Loss: 24.9440, Test Loss: 20.6817
# Epoch 5/15, Train Loss: 18.1600, Test Loss: 15.9750
# Epoch 6/15, Train Loss: 13.6158, Test Loss: 11.5833
# Epoch 7/15, Train Loss: 10.1919, Test Loss: 9.0487
# Epoch 8/15, Train Loss: 7.6264, Test Loss: 6.3990
# Epoch 9/15, Train Loss: 5.5346, Test Loss: 5.0066
# Epoch 10/15, Train Loss: 4.0212, Test Loss: 3.3634
# Epoch 11/15, Train Loss: 2.8922, Test Loss: 2.3961
# Epoch 12/15, Train Loss: 2.1094, Test Loss: 1.7789
# Epoch 13/15, Train Loss: 1.6229, Test Loss: 1.4175
# Epoch 14/15, Train Loss: 1.3293, Test Loss: 1.2125
# Epoch 15/15, Train Loss: 1.1693, Test Loss: 1.1040

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # More Complex Hybrid Model
# The model's loss dropping drastically and then remaining stable might indicate underfitting. So, let's try adding additional convolutional layers.

# %%
num_feats = 44
seq_length = 50  
model = ComplexHybridCNNRegression(num_features=num_feats, seq_length=seq_length).to(device)
criterion = nn.MSELoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 15

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/15, Train Loss: 87.4872, Test Loss: 683.6560
# Epoch 2/15, Train Loss: 24.8203, Test Loss: 698.9762
# Epoch 3/15, Train Loss: 19.8224, Test Loss: 688.6028
# Epoch 4/15, Train Loss: 11.4954, Test Loss: 691.1800

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # Temporal CNN
# Our more complex hybrid CNN was massively overfitting, so let's go in a different direction. Let's try a temporal CNN instead.

# %%
num_feats = 44
seq_length = 50
model = TCNRegression(num_features=num_feats, seq_length=seq_length).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
plot_loss(history)
# Out:
# Epoch 1/20, Train Loss: 83.9557, Test Loss: 105.7673
# Epoch 2/20, Train Loss: 16.7025, Test Loss: 105.0133
# Epoch 3/20, Train Loss: 12.0502, Test Loss: 32.9945
# Epoch 4/20, Train Loss: 9.0328, Test Loss: 39.9333
# Epoch 5/20, Train Loss: 6.6679, Test Loss: 24.8214
# Epoch 6/20, Train Loss: 4.6433, Test Loss: 25.9090
# Epoch 7/20, Train Loss: 3.1718, Test Loss: 24.1333
# Epoch 8/20, Train Loss: 2.2301, Test Loss: 23.1552
# Epoch 9/20, Train Loss: 1.8244, Test Loss: 20.4134
# Epoch 10/20, Train Loss: 1.4287, Test Loss: 19.6762
# Epoch 11/20, Train Loss: 1.2589, Test Loss: 21.6085
# Epoch 12/20, Train Loss: 1.1109, Test Loss: 16.5766
# Epoch 13/20, Train Loss: 0.9482, Test Loss: 18.6676
# Epoch 14/20, Train Loss: 0.8916, Test Loss: 18.4272
# Epoch 15/20, Train Loss: 0.7810, Test Loss: 17.6780

# %%
plot_rul_predictions(model, test_loader, device)
