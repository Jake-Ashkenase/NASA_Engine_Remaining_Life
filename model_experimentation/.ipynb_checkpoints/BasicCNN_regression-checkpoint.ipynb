# %% [markdown]
# # Setup
# We need datasets, dataloaders, and code to train and evaluate models

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %%
import os
import sys
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)
from models import *
from data_structures import *
from helpers import load_from_hdf5

# %%
X, y = load_from_hdf5(filename="../../engine_windows_sample_scaled.h5")

# %%
threshold = 20
idxs = np.where(y < threshold)[0]
X = X[idxs]
y = y[idxs]

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

# %% [markdown]
# # 1d CNN
# First, let's try a one dimensional CNN to capture temporal relationships within each feature.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y)

# %%
num_feats = 44
model = CNNRULRegression(num_features=num_feats).to(device)
criterion = nn.MSELoss() 
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20 

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # 2d CNN
# Now, let's try out a two dimensional CNN to capture interactions among features.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y, dim="2d")

# %%
num_feats = 44
model = CNNRUL2DRegression(num_features=num_feats).to(device)
criterion = nn.MSELoss() 
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 15 

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # Hybrid CNN
# Now, let's try a hybrid CNN that uses both 1d and 2d convolutions.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y)

# %%
num_feats = 33
seq_length = 50  
model = HybridCNNRegression(num_features=num_feats, seq_length=seq_length).to(device)
criterion = nn.MSELoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 30

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/30, Train Loss: 39.2477, Test Loss: 33.4907
# Epoch 2/30, Train Loss: 33.1381, Test Loss: 32.9959
# Epoch 3/30, Train Loss: 32.6687, Test Loss: 32.6684
# Epoch 4/30, Train Loss: 32.1488, Test Loss: 31.9431
# Epoch 5/30, Train Loss: 31.5061, Test Loss: 31.2703
# Epoch 6/30, Train Loss: 30.8166, Test Loss: 30.5425
# Epoch 7/30, Train Loss: 30.0496, Test Loss: 29.7538
# Epoch 8/30, Train Loss: 29.2063, Test Loss: 28.8716
# Epoch 9/30, Train Loss: 28.2439, Test Loss: 28.0019
# Epoch 10/30, Train Loss: 27.1933, Test Loss: 26.7722
# Epoch 11/30, Train Loss: 26.0167, Test Loss: 25.5163
# Epoch 12/30, Train Loss: 24.7689, Test Loss: 24.2300
# Epoch 13/30, Train Loss: 23.4529, Test Loss: 22.8519
# Epoch 14/30, Train Loss: 22.0592, Test Loss: 21.4494
# Epoch 15/30, Train Loss: 20.6478, Test Loss: 20.0302
# Epoch 16/30, Train Loss: 19.2944, Test Loss: 18.8622
# Epoch 17/30, Train Loss: 18.0012, Test Loss: 17.4705
# Epoch 18/30, Train Loss: 16.8201, Test Loss: 16.3360
# Epoch 19/30, Train Loss: 15.7486, Test Loss: 15.3397
# Epoch 20/30, Train Loss: 14.8154, Test Loss: 14.4067
# Epoch 21/30, Train Loss: 13.9862, Test Loss: 13.6460
# Epoch 22/30, Train Loss: 13.2876, Test Loss: 12.9473
# Epoch 23/30, Train Loss: 12.6817, Test Loss: 12.4339
# Epoch 24/30, Train Loss: 12.1565, Test Loss: 12.1902
# Epoch 25/30, Train Loss: 11.7178, Test Loss: 12.0670
# Epoch 26/30, Train Loss: 11.3460, Test Loss: 11.2846
# Epoch 27/30, Train Loss: 10.9953, Test Loss: 10.8227
# Epoch 28/30, Train Loss: 10.6931, Test Loss: 10.5410
# Epoch 29/30, Train Loss: 10.4548, Test Loss: 10.2549
# Epoch 30/30, Train Loss: 10.2233, Test Loss: 10.3348

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # Hybrid CNN with Custom Loss Function
# Now, let's try a hybrid CNN that uses both 1d and 2d convolutions, this time with a custom loss function that penalizes overestimations more then underestimations.

# %%
num_feats = 33
seq_length = 50  
model = HybridCNNRegression(num_features=num_feats, seq_length=seq_length).to(device)
criterion = AsymmetricHuberLoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00003)
num_epochs = 30

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/30, Train Loss: 8.9969, Test Loss: 9.0412
# Epoch 2/30, Train Loss: 8.9966, Test Loss: 9.0412
# Epoch 3/30, Train Loss: 8.9966, Test Loss: 9.0412
# Epoch 4/30, Train Loss: 8.9966, Test Loss: 9.0412
# Epoch 5/30, Train Loss: 8.9970, Test Loss: 9.0412
# Epoch 6/30, Train Loss: 8.9970, Test Loss: 9.0412
# Epoch 7/30, Train Loss: 8.9969, Test Loss: 9.0412
# Epoch 8/30, Train Loss: 8.9965, Test Loss: 9.0412
# Epoch 9/30, Train Loss: 8.9965, Test Loss: 9.0412
# Epoch 10/30, Train Loss: 8.9965, Test Loss: 9.0412
# Epoch 11/30, Train Loss: 8.9969, Test Loss: 9.0412
# Epoch 12/30, Train Loss: 8.9969, Test Loss: 9.0412
# Epoch 13/30, Train Loss: 8.9971, Test Loss: 9.0412
# Epoch 14/30, Train Loss: 8.9968, Test Loss: 9.0412
# Epoch 15/30, Train Loss: 8.9968, Test Loss: 9.0412
# Epoch 16/30, Train Loss: 8.9969, Test Loss: 9.0412
# Epoch 17/30, Train Loss: 8.9964, Test Loss: 9.0412
# Epoch 18/30, Train Loss: 8.9966, Test Loss: 9.0412
# Epoch 19/30, Train Loss: 8.9963, Test Loss: 9.0412
# Epoch 20/30, Train Loss: 8.9967, Test Loss: 9.0412
# Epoch 21/30, Train Loss: 8.9967, Test Loss: 9.0412
# Epoch 22/30, Train Loss: 8.9965, Test Loss: 9.0412
# Epoch 23/30, Train Loss: 8.9967, Test Loss: 9.0412
# Epoch 24/30, Train Loss: 8.9966, Test Loss: 9.0412
# Epoch 25/30, Train Loss: 8.9969, Test Loss: 9.0412
# Epoch 26/30, Train Loss: 8.9966, Test Loss: 9.0412
# Epoch 27/30, Train Loss: 8.9969, Test Loss: 9.0412
# Epoch 28/30, Train Loss: 8.9968, Test Loss: 9.0412
# Epoch 29/30, Train Loss: 8.9967, Test Loss: 9.0412
# Epoch 30/30, Train Loss: 8.9967, Test Loss: 9.0412

# %%
plot_loss(history)
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # More Complex Hybrid Model
# The model's loss dropping drastically and then remaining stable might indicate underfitting. So, let's try adding additional convolutional layers.

# %%
num_feats = 44
seq_length = 50  
model = ComplexHybridCNNRegression(num_features=num_feats, seq_length=seq_length).to(device)
criterion = nn.MSELoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 15

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)

# %% [markdown]
# # Temporal CNN
# Our more complex hybrid CNN was massively overfitting, so let's go in a different direction. Let's try a temporal CNN instead.

# %%
num_feats = 44
seq_length = 50
model = TCNRegression(num_features=num_feats, seq_length=seq_length).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device)
