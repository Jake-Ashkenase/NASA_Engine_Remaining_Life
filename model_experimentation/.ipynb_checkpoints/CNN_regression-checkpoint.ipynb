# %% [markdown]
# # Setup
# We need datasets, dataloaders, and code to train and evaluate models

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from collections import Counter

# %%
import os
import sys
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)
from models import *
from data_structures import *
from helpers import load_from_hdf5

# %%
X_original, y = load_from_hdf5(filename="../../engine_final_scaled.h5")

# %%
y_hs = X_original[:, 0, 44]
X = X_original[:, :, :44]
print(y_hs.shape)
print(X.shape)
print(y.shape)
# Out:
# (500000,)
# (500000, 50, 44)
# (500000,)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

# %% [markdown]
# # 1d CNN
# First, let's try a one dimensional CNN to capture temporal relationships within each feature.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y)
# Out:
# Train set size: 400000, Test set size: 100000

# %%
num_feats = 44
model = CNNRULRegression(num_features=num_feats).to(device)
criterion = nn.MSELoss() 
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20 
history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 585.0929, Test Loss: 207.0237
# Epoch 2/20, Train Loss: 111.5425, Test Loss: 99.4622
# Epoch 3/20, Train Loss: 96.0884, Test Loss: 93.5042
# Epoch 4/20, Train Loss: 90.5469, Test Loss: 87.9529
# Epoch 5/20, Train Loss: 85.3175, Test Loss: 84.1862
# Epoch 6/20, Train Loss: 80.5278, Test Loss: 78.3959
# Epoch 7/20, Train Loss: 76.0247, Test Loss: 73.8195
# Epoch 8/20, Train Loss: 72.1017, Test Loss: 70.2100
# Epoch 9/20, Train Loss: 68.5156, Test Loss: 66.4956
# Epoch 10/20, Train Loss: 65.2090, Test Loss: 63.2617
# Epoch 11/20, Train Loss: 62.1371, Test Loss: 60.1744
# Epoch 12/20, Train Loss: 59.2859, Test Loss: 59.7496
# Epoch 13/20, Train Loss: 56.7660, Test Loss: 55.9526
# Epoch 14/20, Train Loss: 54.5092, Test Loss: 53.0049
# Epoch 15/20, Train Loss: 52.7743, Test Loss: 51.3134
# Epoch 16/20, Train Loss: 51.0715, Test Loss: 51.8512
# Epoch 17/20, Train Loss: 49.7112, Test Loss: 48.2181
# Epoch 18/20, Train Loss: 48.4800, Test Loss: 47.5568
# Epoch 19/20, Train Loss: 47.2836, Test Loss: 46.8072
# Epoch 20/20, Train Loss: 46.2753, Test Loss: 48.0952

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/baseline_state_dict.pth')

# %% [markdown]
# # 2d CNN
# Now, let's try out a two dimensional CNN to capture interactions among features.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y, dim="2d")
# Out:
# Train set size: 400000, Test set size: 100000

# %%
num_feats = 44
model = CNNRUL2DRegression(num_features=num_feats).to(device)
criterion = nn.MSELoss() 
optimizer = optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

# %%
state_dict = torch.load('state_dicts/freq_mse_huber_unhealthy_state_dict.pth')
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 481.4951, Test Loss: 133.3896
# Epoch 2/20, Train Loss: 110.5404, Test Loss: 101.1573
# Epoch 3/20, Train Loss: 96.1761, Test Loss: 93.3354
# Epoch 4/20, Train Loss: 88.3841, Test Loss: 85.1064
# Epoch 5/20, Train Loss: 81.8370, Test Loss: 79.0464
# Epoch 6/20, Train Loss: 75.9867, Test Loss: 74.2371
# Epoch 7/20, Train Loss: 70.5496, Test Loss: 68.0125
# Epoch 8/20, Train Loss: 65.6830, Test Loss: 63.4238
# Epoch 9/20, Train Loss: 61.3310, Test Loss: 59.3950
# Epoch 10/20, Train Loss: 57.5427, Test Loss: 55.9389
# Epoch 11/20, Train Loss: 54.1231, Test Loss: 53.0500
# Epoch 12/20, Train Loss: 51.1528, Test Loss: 49.8934
# Epoch 13/20, Train Loss: 48.5926, Test Loss: 47.8963
# Epoch 14/20, Train Loss: 46.3497, Test Loss: 45.3997
# Epoch 15/20, Train Loss: 44.4562, Test Loss: 43.6229
# Epoch 16/20, Train Loss: 42.8599, Test Loss: 42.2396
# Epoch 17/20, Train Loss: 41.5427, Test Loss: 40.9136
# Epoch 18/20, Train Loss: 40.3662, Test Loss: 39.9375
# Epoch 19/20, Train Loss: 39.3116, Test Loss: 39.5968
# Epoch 20/20, Train Loss: 38.3329, Test Loss: 40.5555

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)
# Out:
# /Volumes/OMAM/NASA_Engine_Remaining_Life/model_experimentation/models/train_eval.py:141: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot([min(actual_rul), max(actual_rul)], [min(actual_rul), max(actual_rul)], 'r--', label="Perfect Prediction", color="#384957")

# %%
idxs = np.where(y_hs == 1)[0]
y_healthy = y[idxs]
X_healthy = X[idxs]
idxs = np.where(y_hs == 0)[0]
y_unhealthy = y[idxs]
X_unhealthy = X[idxs ]
healthy_train_loader, healthy_test_loader = create_train_test_dataloaders(X_healthy, y_healthy, dim="2d")
unhealthy_train_loader, unhealthy_test_loader = create_train_test_dataloaders(X_unhealthy, y_unhealthy, dim="2d")
# Out:
# Train set size: 109272, Test set size: 27319
# Train set size: 290727, Test set size: 72682

# %%
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)
# Out:
# /Volumes/OMAM/NASA_Engine_Remaining_Life/model_experimentation/models/train_eval.py:141: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot([min(actual_rul), max(actual_rul)], [min(actual_rul), max(actual_rul)], 'r--', label="Perfect Prediction", color="#384957")

# %%
plot_rul_predictions(model, unhealthy_test_loader, device, aggregate=True, shaded_region=True)
# Out:
# /Volumes/OMAM/NASA_Engine_Remaining_Life/model_experimentation/models/train_eval.py:141: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot([min(actual_rul), max(actual_rul)], [min(actual_rul), max(actual_rul)], 'r--', label="Perfect Prediction", color="#384957")

# %%
torch.save(model.state_dict(), 'state_dicts/2d_baseline_state_dict.pth')

# %% [markdown]
# # Hybrid CNN
# Now, let's try a hybrid CNN that uses both 1d and 2d convolutions.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y)
# Out:
# Train set size: 400000, Test set size: 100000

# %%
num_feats = 44
seq_length = 50  
model = HybridCNNRegression(num_features=num_feats, seq_length=seq_length).to(device)
criterion = nn.MSELoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20
history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 414.8192, Test Loss: 154.9831
# Epoch 2/20, Train Loss: 114.4205, Test Loss: 100.5858
# Epoch 3/20, Train Loss: 94.7158, Test Loss: 90.1659
# Epoch 4/20, Train Loss: 86.3942, Test Loss: 82.3945
# Epoch 5/20, Train Loss: 79.5305, Test Loss: 75.9043
# Epoch 6/20, Train Loss: 73.3605, Test Loss: 70.0486
# Epoch 7/20, Train Loss: 67.9850, Test Loss: 64.9515
# Epoch 8/20, Train Loss: 63.2206, Test Loss: 60.7965
# Epoch 9/20, Train Loss: 59.1268, Test Loss: 56.7047
# Epoch 10/20, Train Loss: 55.7703, Test Loss: 53.6872
# Epoch 11/20, Train Loss: 53.1030, Test Loss: 51.3821
# Epoch 12/20, Train Loss: 50.9560, Test Loss: 49.4698
# Epoch 13/20, Train Loss: 49.3743, Test Loss: 48.4467
# Epoch 14/20, Train Loss: 48.0740, Test Loss: 47.1024
# Epoch 15/20, Train Loss: 47.0102, Test Loss: 46.4974
# Epoch 16/20, Train Loss: 46.1387, Test Loss: 45.2280
# Epoch 17/20, Train Loss: 45.4210, Test Loss: 45.8885
# Epoch 18/20, Train Loss: 44.7998, Test Loss: 44.1483
# Epoch 19/20, Train Loss: 44.2056, Test Loss: 43.4197
# Epoch 20/20, Train Loss: 43.7034, Test Loss: 42.8889

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/hybrid_baseline_state_dict.pth')

# %% [markdown]
# # 2D CNN with Custom Loss Function and ReLU on Final Layer
# Now, let's try a 2D CNN that uses both 1d and 2d convolutions, this time with a custom loss function that penalizes overestimations more then underestimations. The 2D baseline was most performant, so that's the route we'll take. Ideally, we should see that the graph of actual versus predicted RULs shows fewer overesimates. Additionally, let's add ReLU activation to the output layer to avoid negative RUL estimates, which are practically impossible.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y, dim="2d")
# Out:
# Train set size: 400000, Test set size: 100000

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
criterion = AsymmetricHuberLoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 21.5657, Test Loss: 12.9371
# Epoch 2/20, Train Loss: 12.3063, Test Loss: 11.6893
# Epoch 3/20, Train Loss: 11.2466, Test Loss: 10.7760
# Epoch 4/20, Train Loss: 10.5199, Test Loss: 10.1822
# Epoch 5/20, Train Loss: 9.9398, Test Loss: 9.6097
# Epoch 6/20, Train Loss: 9.4492, Test Loss: 9.1948
# Epoch 7/20, Train Loss: 9.0592, Test Loss: 9.1089
# Epoch 8/20, Train Loss: 8.7233, Test Loss: 8.5455
# Epoch 9/20, Train Loss: 8.4464, Test Loss: 8.2608
# Epoch 10/20, Train Loss: 8.2119, Test Loss: 8.0621
# Epoch 11/20, Train Loss: 8.0071, Test Loss: 7.9863
# Epoch 12/20, Train Loss: 7.8014, Test Loss: 7.6710
# Epoch 13/20, Train Loss: 7.6097, Test Loss: 7.5346
# Epoch 14/20, Train Loss: 7.4482, Test Loss: 7.6493
# Epoch 15/20, Train Loss: 7.2769, Test Loss: 7.7135
# Epoch 16/20, Train Loss: 7.1209, Test Loss: 6.9715
# Epoch 17/20, Train Loss: 6.9634, Test Loss: 6.8161
# Epoch 18/20, Train Loss: 6.8276, Test Loss: 6.6711
# Epoch 19/20, Train Loss: 6.6833, Test Loss: 6.5499
# Epoch 20/20, Train Loss: 6.5713, Test Loss: 6.4501

# %%
plot_loss(history)

# %%
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/custom_loss_state_dict.pth')

# %% [markdown]
# # Frequency Weighted MSE 2D CNN

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
freq_map = {k:v for k, v in Counter(y).items()}
criterion = FrequencyWeightedMSELoss(freq_map) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 0.4687, Test Loss: 0.1086
# Epoch 2/20, Train Loss: 0.0909, Test Loss: 0.0841
# Epoch 3/20, Train Loss: 0.0807, Test Loss: 0.0771
# Epoch 4/20, Train Loss: 0.0746, Test Loss: 0.0723
# Epoch 5/20, Train Loss: 0.0704, Test Loss: 0.0686
# Epoch 6/20, Train Loss: 0.0673, Test Loss: 0.0666
# Epoch 7/20, Train Loss: 0.0648, Test Loss: 0.0634
# Epoch 8/20, Train Loss: 0.0625, Test Loss: 0.0615
# Epoch 9/20, Train Loss: 0.0604, Test Loss: 0.0594
# Epoch 10/20, Train Loss: 0.0585, Test Loss: 0.0584
# Epoch 11/20, Train Loss: 0.0566, Test Loss: 0.0562
# Epoch 12/20, Train Loss: 0.0547, Test Loss: 0.0539
# Epoch 13/20, Train Loss: 0.0530, Test Loss: 0.0529
# Epoch 14/20, Train Loss: 0.0513, Test Loss: 0.0508
# Epoch 15/20, Train Loss: 0.0496, Test Loss: 0.0491
# Epoch 16/20, Train Loss: 0.0480, Test Loss: 0.0476
# Epoch 17/20, Train Loss: 0.0465, Test Loss: 0.0459
# Epoch 18/20, Train Loss: 0.0451, Test Loss: 0.0443
# Epoch 19/20, Train Loss: 0.0438, Test Loss: 0.0432
# Epoch 20/20, Train Loss: 0.0426, Test Loss: 0.0422

# %%
plot_loss(history)
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/freq_mse_state_dict.pth')

# %%
state_dict = torch.load('state_dicts/freq_mse_state_dict.pth')
model = CNNRUL2DRegression(num_features=44).to(device)
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
plot_rul_predictions(model, unhealthy_test_loader, device, aggregate=True, shaded_region=True)

# %% [markdown]
# ## By Engine Health

# %%
idxs = np.where(y_hs == 1)[0]
y_healthy = y[idxs]
X_healthy = X[idxs]
idxs = np.where(y_hs == 0)[0]
y_unhealthy = y[idxs]
X_unhealthy = X[idxs ]
healthy_freq_map = {k:v for k, v in Counter(y_healthy).items()}
unhealthy_freq_map = {k:v for k, v in Counter(y_unhealthy).items()}
healthy_train_loader, healthy_test_loader = create_train_test_dataloaders(X_healthy, y_healthy, dim="2d")
unhealthy_train_loader, unhealthy_test_loader = create_train_test_dataloaders(X_unhealthy, y_unhealthy, dim="2d")
# Out:
# Train set size: 109272, Test set size: 27319
# Train set size: 290727, Test set size: 72682

# %% [markdown]
# ### Healthy Engines

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
criterion = FrequencyWeightedMSELoss(healthy_freq_map) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
num_epochs = 20

history = train_model(model, healthy_train_loader, healthy_test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 1.7163, Test Loss: 0.5626
# Epoch 2/20, Train Loss: 0.5708, Test Loss: 0.5580
# Epoch 3/20, Train Loss: 0.5649, Test Loss: 0.5506
# Epoch 4/20, Train Loss: 0.5570, Test Loss: 0.5405
# Epoch 5/20, Train Loss: 0.5444, Test Loss: 0.5252
# Epoch 6/20, Train Loss: 0.5253, Test Loss: 0.5013
# Epoch 7/20, Train Loss: 0.4935, Test Loss: 0.4606
# Epoch 8/20, Train Loss: 0.4431, Test Loss: 0.4016
# Epoch 9/20, Train Loss: 0.3801, Test Loss: 0.3421
# Epoch 10/20, Train Loss: 0.3318, Test Loss: 0.3093
# Epoch 11/20, Train Loss: 0.3120, Test Loss: 0.3003
# Epoch 12/20, Train Loss: 0.3063, Test Loss: 0.2980
# Epoch 13/20, Train Loss: 0.3043, Test Loss: 0.2968
# Epoch 14/20, Train Loss: 0.3032, Test Loss: 0.2956
# Epoch 15/20, Train Loss: 0.3019, Test Loss: 0.2940
# Epoch 16/20, Train Loss: 0.3007, Test Loss: 0.2927
# Epoch 17/20, Train Loss: 0.2995, Test Loss: 0.2918
# Epoch 18/20, Train Loss: 0.2981, Test Loss: 0.2901
# Epoch 19/20, Train Loss: 0.2966, Test Loss: 0.2886
# Epoch 20/20, Train Loss: 0.2952, Test Loss: 0.2869

# %%
num_feats = 44
state_dict = torch.load('state_dicts/freq_mse_healthy_state_dict.pth')
model = CNNRUL2DRegression(num_features=num_feats).to(device)
model.load_state_dict(state_dict)
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs=20

# %%
criterion = FrequencyWeightedAsymmetricHuberLoss(healthy_freq_map) 
history = train_model(model, healthy_train_loader, healthy_test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 0.0097, Test Loss: 0.0095
# Epoch 2/20, Train Loss: 0.0095, Test Loss: 0.0095
# Epoch 3/20, Train Loss: 0.0095, Test Loss: 0.0094
# Epoch 4/20, Train Loss: 0.0095, Test Loss: 0.0096
# Epoch 5/20, Train Loss: 0.0094, Test Loss: 0.0093
# Epoch 6/20, Train Loss: 0.0094, Test Loss: 0.0094
# Epoch 7/20, Train Loss: 0.0094, Test Loss: 0.0093
# Epoch 8/20, Train Loss: 0.0094, Test Loss: 0.0093
# Epoch 9/20, Train Loss: 0.0093, Test Loss: 0.0092
# Epoch 10/20, Train Loss: 0.0093, Test Loss: 0.0094
# Epoch 11/20, Train Loss: 0.0093, Test Loss: 0.0092
# Epoch 12/20, Train Loss: 0.0093, Test Loss: 0.0093
# Epoch 13/20, Train Loss: 0.0093, Test Loss: 0.0095
# Epoch 14/20, Train Loss: 0.0093, Test Loss: 0.0093
# Epoch 15/20, Train Loss: 0.0093, Test Loss: 0.0095
# Epoch 16/20, Train Loss: 0.0093, Test Loss: 0.0091
# Epoch 17/20, Train Loss: 0.0092, Test Loss: 0.0092
# Epoch 18/20, Train Loss: 0.0092, Test Loss: 0.0091
# Epoch 19/20, Train Loss: 0.0092, Test Loss: 0.0091
# Epoch 20/20, Train Loss: 0.0092, Test Loss: 0.0093

# %%
# with huber asymmetric mse frequency weighted loss
plot_loss(history)
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
# with basic mse frequency weighted loss
plot_loss(history)
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/freq_mse_healthy_state_dict.pth')

# %%
torch.save(model.state_dict(), 'state_dicts/freq_mse_huber_healthy_state_dict.pth')

# %% [markdown]
# ### Unhealthy Engines

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
criterion = FrequencyWeightedMSELoss(unhealthy_freq_map) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

history = train_model(model, unhealthy_train_loader, unhealthy_test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 0.4759, Test Loss: 0.3802
# Epoch 2/20, Train Loss: 0.3127, Test Loss: 0.2134
# Epoch 3/20, Train Loss: 0.1413, Test Loss: 0.1086
# Epoch 4/20, Train Loss: 0.0975, Test Loss: 0.0894
# Epoch 5/20, Train Loss: 0.0853, Test Loss: 0.0802
# Epoch 6/20, Train Loss: 0.0774, Test Loss: 0.0733
# Epoch 7/20, Train Loss: 0.0709, Test Loss: 0.0670
# Epoch 8/20, Train Loss: 0.0651, Test Loss: 0.0619
# Epoch 9/20, Train Loss: 0.0600, Test Loss: 0.0571
# Epoch 10/20, Train Loss: 0.0555, Test Loss: 0.0541
# Epoch 11/20, Train Loss: 0.0513, Test Loss: 0.0489
# Epoch 12/20, Train Loss: 0.0479, Test Loss: 0.0456
# Epoch 13/20, Train Loss: 0.0448, Test Loss: 0.0431
# Epoch 14/20, Train Loss: 0.0423, Test Loss: 0.0406
# Epoch 15/20, Train Loss: 0.0403, Test Loss: 0.0389
# Epoch 16/20, Train Loss: 0.0386, Test Loss: 0.0376
# Epoch 17/20, Train Loss: 0.0372, Test Loss: 0.0387
# Epoch 18/20, Train Loss: 0.0360, Test Loss: 0.0368
# Epoch 19/20, Train Loss: 0.0349, Test Loss: 0.0352
# Epoch 20/20, Train Loss: 0.0340, Test Loss: 0.0361

# %%
history = train_model(model, unhealthy_train_loader, unhealthy_test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 0.0209, Test Loss: 0.0203
# Epoch 2/20, Train Loss: 0.0207, Test Loss: 0.0214
# Epoch 3/20, Train Loss: 0.0206, Test Loss: 0.0202
# Epoch 4/20, Train Loss: 0.0205, Test Loss: 0.0203
# Epoch 5/20, Train Loss: 0.0204, Test Loss: 0.0199
# Epoch 6/20, Train Loss: 0.0204, Test Loss: 0.0197
# Epoch 7/20, Train Loss: 0.0203, Test Loss: 0.0201
# Epoch 8/20, Train Loss: 0.0202, Test Loss: 0.0199
# Epoch 9/20, Train Loss: 0.0201, Test Loss: 0.0217
# Epoch 10/20, Train Loss: 0.0199, Test Loss: 0.0198
# Epoch 11/20, Train Loss: 0.0199, Test Loss: 0.0194
# Epoch 12/20, Train Loss: 0.0198, Test Loss: 0.0193
# Epoch 13/20, Train Loss: 0.0198, Test Loss: 0.0194
# Epoch 14/20, Train Loss: 0.0198, Test Loss: 0.0195
# Epoch 15/20, Train Loss: 0.0197, Test Loss: 0.0219
# Epoch 16/20, Train Loss: 0.0196, Test Loss: 0.0199
# Epoch 17/20, Train Loss: 0.0195, Test Loss: 0.0189
# Epoch 18/20, Train Loss: 0.0194, Test Loss: 0.0188
# Epoch 19/20, Train Loss: 0.0194, Test Loss: 0.0188
# Epoch 20/20, Train Loss: 0.0193, Test Loss: 0.0193

# %%
plot_loss(history)
plot_rul_predictions(model, unhealthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
# with huber inverse frequency weighting
state_dict = torch.load('state_dicts/freq_mse_unhealthy_state_dict.pth')
model = CNNRUL2DRegression(num_features=44).to(device)
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs=20
criterion = FrequencyWeightedAsymmetricHuberLoss(unhealthy_freq_map) 
history = train_model(model, unhealthy_train_loader, unhealthy_test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 0.0039, Test Loss: 0.0038
# Epoch 2/20, Train Loss: 0.0038, Test Loss: 0.0038
# Epoch 3/20, Train Loss: 0.0038, Test Loss: 0.0037
# Epoch 4/20, Train Loss: 0.0038, Test Loss: 0.0037
# Epoch 5/20, Train Loss: 0.0038, Test Loss: 0.0037
# Epoch 6/20, Train Loss: 0.0037, Test Loss: 0.0037
# Epoch 7/20, Train Loss: 0.0037, Test Loss: 0.0037
# Epoch 8/20, Train Loss: 0.0037, Test Loss: 0.0037
# Epoch 9/20, Train Loss: 0.0037, Test Loss: 0.0036
# Epoch 10/20, Train Loss: 0.0037, Test Loss: 0.0036
# Epoch 11/20, Train Loss: 0.0037, Test Loss: 0.0036
# Epoch 12/20, Train Loss: 0.0036, Test Loss: 0.0035
# Epoch 13/20, Train Loss: 0.0036, Test Loss: 0.0036
# Epoch 14/20, Train Loss: 0.0036, Test Loss: 0.0035
# Epoch 15/20, Train Loss: 0.0036, Test Loss: 0.0035
# Epoch 16/20, Train Loss: 0.0036, Test Loss: 0.0035
# Epoch 17/20, Train Loss: 0.0036, Test Loss: 0.0035
# Epoch 18/20, Train Loss: 0.0036, Test Loss: 0.0035
# Epoch 19/20, Train Loss: 0.0035, Test Loss: 0.0035
# Epoch 20/20, Train Loss: 0.0035, Test Loss: 0.0035

# %%
torch.save(model.state_dict(), 'state_dicts/freq_mse_huber_unhealthy_state_dict.pth')

# %% [markdown]
# # Understanding Performance Differences for Healthy vs Unhealthy Engines
# Healthy engines are much more prone to drastic underestimations as actual RUL increases. Unhealthy engines share this trend, but less so that healthy ones. Unhealthy engines tend to have pretty good predictions up until around 40 actual RUL. This seems to indicate that the model struggles around the boundary of healthy versus unhealthy engines and that the model struggles for both healthy and unhealthy engines as actual RUL increases. It is true that we'd rather have underestimates of RUL than overestimates, as is occuring. But, we still want to try to minimize these error trends.

# %%
idxs = np.where(y_hs == 1)[0]
X_healthy = X[idxs]
y_healthy = y[idxs]
healthy_train_loader, healthy_test_loader = create_train_test_dataloaders(X_healthy, y_healthy, dim="2d")
#plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)
# Out:
# Train set size: 109272, Test set size: 27319

# %%
idxs = np.where(y_hs == 0)[0]
X_unhealthy = X[idxs]
y_unhealthy = y[idxs]
unhealthy_train_loader, unhealthy_test_loader = create_train_test_dataloaders(X_unhealthy, y_unhealthy, dim="2d")
#plot_rul_predictions(model, unhealthy_test_loader, device, aggregate=True, shaded_region=True)
# Out:
# Train set size: 290727, Test set size: 72682

# %% [markdown]
# # 2D CNN with Custom Loss Function and ReLU on Final Layer for Healthy and Unhealthy Engines
# Now, let's try the same 2D architecture as before for only healthy engines and then for only unhealthy engines and see if it is more performant than the original 2D model with custom loss.
# ### Healthy Engines

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
criterion = AsymmetricHuberLoss(beta=3) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00002)
num_epochs = 10

history = train_model(model, healthy_train_loader, healthy_test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 21.4343, Test Loss: 17.3375
# Epoch 2/20, Train Loss: 17.3530, Test Loss: 17.2403
# Epoch 3/20, Train Loss: 17.2284, Test Loss: 17.1619
# Epoch 4/20, Train Loss: 16.9738, Test Loss: 16.7658
# Epoch 5/20, Train Loss: 16.3891, Test Loss: 15.8364
# Epoch 6/20, Train Loss: 15.4411, Test Loss: 14.9377
# Epoch 7/20, Train Loss: 14.8705, Test Loss: 14.6392
# Epoch 8/20, Train Loss: 14.6835, Test Loss: 14.4744
# Epoch 9/20, Train Loss: 14.5216, Test Loss: 14.3140
# Epoch 10/20, Train Loss: 14.3573, Test Loss: 14.1109
# Epoch 11/20, Train Loss: 14.1667, Test Loss: 13.9097
# Epoch 12/20, Train Loss: 13.9585, Test Loss: 13.7095
# Epoch 13/20, Train Loss: 13.7182, Test Loss: 13.4424
# Epoch 14/20, Train Loss: 13.4390, Test Loss: 13.1252
# Epoch 15/20, Train Loss: 13.1437, Test Loss: 12.9795
# Epoch 16/20, Train Loss: 12.8418, Test Loss: 12.5294
# Epoch 17/20, Train Loss: 12.5165, Test Loss: 12.1702
# Epoch 18/20, Train Loss: 12.2149, Test Loss: 12.1554
# Epoch 19/20, Train Loss: 11.9204, Test Loss: 11.5721
# Epoch 20/20, Train Loss: 11.6099, Test Loss: 11.2983

# %%
# after 20 epochs
plot_loss(history)
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/healthy_state_dict.pth')

# %% [markdown]
# ### Unhealthy Engines

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
criterion = AsymmetricHuberLoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

history = train_model(model, unhealthy_train_loader, unhealthy_test_loader, criterion, optimizer, device, num_epochs=num_epochs)

# %%
plot_loss(history)
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/unhealthy_state_dict.pth')

# %% [markdown]
# # 2D CNN with Frequency Based Smoothing Asymmetric Custom Loss Function and ReLU on Final Layer for Healthy and Unhealthy Engines Together
# Simply using the same architecture for healthy and unhealthy engines separately did not result in the desired model improvements. We still see good RUL prediction for low RUL values for unhealthy engines and substantial underestimates for both healthy and unhealthy engines as RUL increased. We still want to maintain the good RUL prediction with penalizing underestimates for low RUL values, but we also want to mitigate the underestimation of high RUL values within both healthy and unhealthy engines, and the overestimation of low RUL values for healthy engines. This might be because those tend to be underrepresented in the data. To address this, we can use a frequency based custom loss function that will still penalize underestimates more while also weighting loss by data frequency.
#
# penalize overestimates as RUL get larger. To do this, we need a new custom loss function that still penalized overestimates for low RUL values while penalizing underestimates as RUL increases. We will try out a smoothing asymmetric huber loss function.

# %%
train_loader, test_loader = create_train_test_dataloaders(X, y, dim="2d")
# Out:
# Train set size: 400000, Test set size: 100000

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
freq_map = {k:v for k, v in Counter(y).items()}
criterion = AdaptiveFrequencyAsymmetricHuberLoss(freq_map) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/20, Train Loss: 212.9871, Test Loss: 151.1756
# Epoch 2/20, Train Loss: 66.0602, Test Loss: 36.4059
# Epoch 3/20, Train Loss: 31.6685, Test Loss: 28.2403
# Epoch 4/20, Train Loss: 26.0072, Test Loss: 24.2745
# Epoch 5/20, Train Loss: 22.5905, Test Loss: 21.0759
# Epoch 6/20, Train Loss: 19.8009, Test Loss: 18.5289
# Epoch 7/20, Train Loss: 17.6675, Test Loss: 16.6944
# Epoch 8/20, Train Loss: 16.0654, Test Loss: 15.2533
# Epoch 9/20, Train Loss: 14.7562, Test Loss: 14.0000
# Epoch 10/20, Train Loss: 13.5675, Test Loss: 12.8343
# Epoch 11/20, Train Loss: 12.4227, Test Loss: 11.7883
# Epoch 12/20, Train Loss: 11.4202, Test Loss: 10.8878
# Epoch 13/20, Train Loss: 10.5818, Test Loss: 10.0572
# Epoch 14/20, Train Loss: 9.9200, Test Loss: 9.5708
# Epoch 15/20, Train Loss: 9.3981, Test Loss: 9.0004
# Epoch 16/20, Train Loss: 8.9640, Test Loss: 8.6263
# Epoch 17/20, Train Loss: 8.5533, Test Loss: 8.4113
# Epoch 18/20, Train Loss: 8.1689, Test Loss: 8.1542
# Epoch 19/20, Train Loss: 7.8180, Test Loss: 7.4962
# Epoch 20/20, Train Loss: 7.4623, Test Loss: 7.6902

# %%
plot_loss(history)
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/freq_asym_custom_loss_state_dict.pth')

# %% [markdown]
# ### With only Healthy Engines

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
freq_map = {k:v for k, v in Counter(y).items()}
criterion = AdaptiveFrequencyAsymmetricHuberLoss(freq_map, base_delta=5.0, min_weight=1.0, max_weight=3.0, overestimate_weight=2.0, underestimate_scale=0.05) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 5

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/5, Train Loss: 219.7523, Test Loss: 178.1340
# Epoch 2/5, Train Loss: 161.5367, Test Loss: 110.1547
# Epoch 3/5, Train Loss: 45.3501, Test Loss: 30.6559
# Epoch 4/5, Train Loss: 28.6757, Test Loss: 26.8441
# Epoch 5/5, Train Loss: 25.7468, Test Loss: 24.3923

# %%
plot_loss(history)
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
freq_map = {k:v for k, v in Counter(y).items()}
criterion = AdaptiveFrequencyAsymmetricHuberLoss(freq_map, base_delta=5.0, min_weight=1.0, max_weight=3.0, overestimate_weight=2.0, underestimate_scale=0.025) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 5

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/5, Train Loss: 621.2013, Test Loss: 621.7253
# Epoch 2/5, Train Loss: 621.2013, Test Loss: 621.7253
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 9>()
#       6 optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
#       7 num_epochs = 5
# ----> 9 history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
#
# File /Volumes/OMAM/NASA_Engine_Remaining_Life/model_experimentation/models/train_eval.py:57, in train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs, track_test_loss)
#      55 optimizer.zero_grad()
#      56 outputs = model(inputs).squeeze()
# ---> 57 loss = criterion(outputs, targets)
#      58 loss.backward()
#      59 optimizer.step()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /Volumes/OMAM/NASA_Engine_Remaining_Life/data_structures/loss_functions.py:99, in AdaptiveFrequencyAsymmetricHuberLoss.forward(self, predictions, targets)
#      95 abs_errors = torch.abs(errors)
#      97 # Frequency-based weight (inverted: rare values get higher weights)
#      98 weights_freq = torch.tensor([self.max_weight / (self.frequency_map.get(float(t), 1) + 1)
# ---> 99                              for t in targets.cpu().numpy()], device=targets.device)
#     100 weights_freq = torch.clamp(weights_freq, self.min_weight, self.max_weight)  # Keep within range
#     102 # Asymmetric weight:
#
# KeyboardInterrupt:

# %%
plot_loss(history)
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %% [markdown]
# ### With Only Unhealthy Engines

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
freq_map = {k:v for k, v in Counter(y_unhealthy).items()}
criterion = AdaptiveFrequencyAsymmetricHuberLoss(freq_map) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

history = train_model(model, unhealthy_train_loader, unhealthy_test_loader, criterion, optimizer, device, num_epochs=num_epochs)

# %%
plot_loss(history)
plot_rul_predictions(model, unhealthy_test_loader, device, aggregate=True, shaded_region=True)

# %% [markdown]
# ### With Different Hyperparameters

# %%
# with different hyperparameters
train_loader, test_loader = create_train_test_dataloaders(X, y, dim="2d")
# Out:
# Train set size: 400000, Test set size: 100000

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DRegression(num_features=num_feats).to(device)
freq_map = {k:v for k, v in Counter(y).items()}
criterion = AdaptiveFrequencyAsymmetricHuberLoss(freq_map) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 10

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/10, Train Loss: 199.0405, Test Loss: 77.3814
# Epoch 2/10, Train Loss: 64.3845, Test Loss: 59.7551
# Epoch 3/10, Train Loss: 56.3432, Test Loss: 53.8442
# Epoch 4/10, Train Loss: 51.5733, Test Loss: 50.1688
# Epoch 5/10, Train Loss: 48.4334, Test Loss: 47.4520
# Epoch 6/10, Train Loss: 46.1241, Test Loss: 45.5053
# Epoch 7/10, Train Loss: 44.1710, Test Loss: 43.4012
# Epoch 8/10, Train Loss: 42.4245, Test Loss: 41.7346
# Epoch 9/10, Train Loss: 40.9205, Test Loss: 40.4623
# Epoch 10/10, Train Loss: 39.6384, Test Loss: 39.5817

# %%
plot_loss(history)
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/freq_asym_custom_loss_two_state_dict.pth')

# %% [markdown]
# # Multi-Task 2D CNN with Custom Loss for Healthy and Unhealthy Engines Together
# It is clear that the differences in healthy versus unhealthy RUL distribution and behavior are making it difficult for out model to accurately capture things in the RUL range that can include both health states and is causing some overestimation and underestimation issues. To resolve this, we will attempt a multi task model that classifies healthy state and then regresses RUL. We were able to very accurately predict health state with a 1D model, so this is certainly worth a try.

# %%
y_combo = np.column_stack((y, y_hs))
train_loader, test_loader = create_train_test_dataloaders(X, y_combo, dim="2d")
# Out:
# Train set size: 400000, Test set size: 100000

# %%
num_feats = 44
seq_length = 50  
model = CNNRUL2DMultiTask(num_features=num_feats).to(device)
#freq_map = {k:v for k, v in Counter(y).items()}
criterion = MultiTaskCriterion() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 5

history = train_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch 1/5, Train Loss: 1.2944, Test Loss: 0.5034
# Epoch 2/5, Train Loss: 0.3467, Test Loss: 0.2806
# Epoch 3/5, Train Loss: 0.2631, Test Loss: 0.2480
# Epoch 4/5, Train Loss: 0.2433, Test Loss: 0.2405
# Epoch 5/5, Train Loss: 0.2347, Test Loss: 0.2303

# %%
plot_loss(history)
plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
pred_rul, actual_rul = model.get_predict_and_true(test_loader, device, classification=True)
acc = calculate_accuracy(np.array(pred_rul).astype(int), np.array(actual_rul).astype(int)) * 100
print(f"Model Accuracy: {acc:.2f}%")
# Out:
# Model Accuracy: 3.50%

# %%
np.unique(np.array(pred_rul).astype(int) == np.array(actual_rul).astype(int), return_counts=True)
# Out:
# (array([False,  True]), array([96499,  3501]))

# %%
idxs = np.where(y_hs == 1)[0]
X_healthy = X[idxs]
y_healthy = y_combo[idxs]
healthy_train_loader, healthy_test_loader = create_train_test_dataloaders(X_healthy, y_healthy, dim="2d")
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)
idxs = np.where(y_hs == 0)[0]
X_healthy = X[idxs]
y_healthy = y_combo[idxs]
healthy_train_loader, healthy_test_loader = create_train_test_dataloaders(X_healthy, y_healthy, dim="2d")
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)
# Out:
# Train set size: 109272, Test set size: 27319
# Train set size: 290727, Test set size: 72682

# %%
torch.save(model.state_dict(), 'state_dicts/mtl_state_dict.pth')

# %% [markdown]
# # 2D CNN with Divergent Health State Branches

# %%
y_combo = np.column_stack((y, y_hs))
#train_loader, test_loader = create_train_test_dataloaders(X_original, y_combo, dim="2d", multitask=True)

# %%
state_dict = torch.load('state_dicts/1d_hs_state_dict.pth')
pretrained_classifier = CNNRULClassifier(num_features=44, num_classes=2).to(device)
pretrained_classifier.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
state_dict = torch.load('state_dicts/freq_mse_unhealthy_state_dict.pth')
pretrained_unhealthy = CNNRUL2DRegression(num_features=44).to(device)
pretrained_unhealthy.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
state_dict = torch.load('state_dicts/freq_mse_healthy_state_dict.pth')
pretrained_healthy = CNNRUL2DRegression(num_features=44).to(device)
pretrained_healthy.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
model = HybridMultiBranchRUL(pretrained_classifier, pretrained_healthy, pretrained_unhealthy).to(device)
#plot_rul_predictions(model, test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/branched_state_dict.pth')

# %%
idxs = np.where(y_hs == 1)[0]
y_healthy = y_combo[idxs]
X_healthy = X_original[idxs]
idxs = np.where(y_hs == 0)[0]
y_unhealthy = y_combo[idxs]
X_unhealthy = X_original[idxs]
#healthy_freq_map = {k:v for k, v in Counter(y_healthy).items()}
#unhealthy_freq_map = {k:v for k, v in Counter(y_unhealthy).items()}
healthy_train_loader, healthy_test_loader = create_train_test_dataloaders(X_healthy, y_healthy, dim="2d", multitask=True)
unhealthy_train_loader, unhealthy_test_loader = create_train_test_dataloaders(X_unhealthy, y_unhealthy, dim="2d", multitask=True)
# Out:
# Train set size: 109272, Test set size: 27319
# Train set size: 290727, Test set size: 72682

# %%
num_feats = 44
seq_length = 50  
model = HybridMultiBranchRUL(num_features=num_feats, pretrained_classifier=pretrained_classifier).to(device)
criterion = FrequencyWeightedBranchedMSELoss(healthy_freq_map, unhealthy_freq_map) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
num_epochs = 20

# %%
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
plot_rul_predictions(model, unhealthy_test_loader, device, aggregate=True, shaded_region=True)

# %% [markdown]
# # 2D with Divergent Health State Branches and Penalizing Overestimates More

# %%
y_combo = np.column_stack((y, y_hs))

state_dict = torch.load('state_dicts/1d_hs_state_dict.pth')
pretrained_classifier = CNNRULClassifier(num_features=44, num_classes=2).to(device)
pretrained_classifier.load_state_dict(state_dict)

state_dict = torch.load('state_dicts/freq_mse_huber_unhealthy_state_dict.pth')
pretrained_unhealthy = CNNRUL2DRegression(num_features=44).to(device)
pretrained_unhealthy.load_state_dict(state_dict)

state_dict = torch.load('state_dicts/freq_mse_huber_healthy_state_dict.pth')
pretrained_healthy = CNNRUL2DRegression(num_features=44).to(device)
pretrained_healthy.load_state_dict(state_dict)

model = HybridMultiBranchRUL(pretrained_classifier, pretrained_healthy, pretrained_unhealthy).to(device)

# %%
idxs = np.where(y_hs == 1)[0]
y_healthy = y_combo[idxs]
X_healthy = X_original[idxs]
idxs = np.where(y_hs == 0)[0]
y_unhealthy = y_combo[idxs]
X_unhealthy = X_original[idxs]
healthy_train_loader, healthy_test_loader = create_train_test_dataloaders(X_healthy, y_healthy, dim="2d", multitask=True)
unhealthy_train_loader, unhealthy_test_loader = create_train_test_dataloaders(X_unhealthy, y_unhealthy, dim="2d", multitask=True)
# Out:
# Train set size: 109272, Test set size: 27319
# Train set size: 290727, Test set size: 72682

# %%
plot_rul_predictions(model, healthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
plot_rul_predictions(model, unhealthy_test_loader, device, aggregate=True, shaded_region=True)

# %%
torch.save(model.state_dict(), 'state_dicts/branched_huber_state_dict.pth')
